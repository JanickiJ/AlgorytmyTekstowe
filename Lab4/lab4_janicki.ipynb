# %% [markdown]
# ## Lab4 Edit distance and lcs

# %%
# -*- coding: utf-8 -*-


from enum import Enum
import codecs
import random
from bisect import bisect
from enum import Enum
from spacy.lang.pl import Polish
from spacy.tokenizer import Tokenizer

# %%
text1a = "los"
text1b = "kloc"
text2a = "Łódź"
text2b = "Lodz"
text3a = "kwintesencja"
text3b = "quintessence"
text4a = "ATGAATCTTACCGCCTCG"
text4b = "ATGAGGCTCTGGCCCCTG"
data = [[text1a,text1b], [text2a,text2b], [text3a,text3b], [text4a,text4b]]

# %% [markdown]
# ### Edit distance

# %%
class Operation(Enum):
    NO_CHANGE = 0
    ADD = 1
    DELETE = 2
    REPLACE = 3

def delta1(a, b):
    return a != b

# %%
def edit_distance(x, y, d):
    path = [[Operation.DELETE for _ in range(len(y) + 1)] for _ in range(len(x) + 1)]
    edit_table = [[float('inf') for _ in range(len(y) + 1)] for _ in range(len(x) + 1)]
    for i in range(len(x) + 1):
        edit_table[i][0] = i
        path[i][0] = Operation.DELETE
    for j in range(len(y) + 1):
        edit_table[0][j] = j
        path[0][j] = Operation.ADD

    for i in range(1, len(x) + 1):
        for j in range(1, len(y) + 1):
            if edit_table[i][j] > edit_table[i - 1][j - 1] + d(x[i - 1], y[j - 1]):
                edit_table[i][j] = edit_table[i - 1][j - 1] + d(x[i - 1], y[j - 1])
                if x[i - 1] == y[i - 1]:
                    path[i][j] = Operation.NO_CHANGE
                else:
                    path[i][j] = Operation.REPLACE

            if edit_table[i][j] > edit_table[i - 1][j] + 1:
                edit_table[i][j] = edit_table[i - 1][j] + 1
                path[i][j] = Operation.DELETE
            if edit_table[i][j] > edit_table[i][j - 1] + 1:
                edit_table[i][j] = edit_table[i][j - 1] + 1
                path[i][j] = Operation.ADD

    return path, edit_table[-1][-1]

# %%
def visualise_edit(x, y, path):
    back_path = []
    i, j = len(x), len(y)
    while i != 0 or j != 0:
        step = path[i][j]
        back_path.append(step)
        if step == Operation.ADD:
            j -= 1
        elif step == Operation.DELETE:
            i -= 1
        else:
            i -= 1
            j -= 1

    forward_path = reversed(back_path)
    i, j = 0, 0
    for direction in forward_path:
        if direction == Operation.NO_CHANGE:
            i += 1
            j += 1
        elif direction == Operation.REPLACE:
            print(f"{x[:i]} : ({x[i]} -> {y[j]}) : {x[i + 1:]}")
            x = x[:i] + y[j] + x[i + 1:]
            i += 1
            j += 1
        elif direction == Operation.DELETE:
            print(f"{x[:i]} * {x[i + 1:]}")
            x = x[:i] + x[i + 1:]
        else:
            print(f"{x[:i]} + {y[j]} + {x[i:]}")
            x = x[:i] + y[j] + x[i:]
            i += 1
            j += 1
    print(x)

# %%
x = "los"
y = "kloc"
print(f"{x} ---> {y}")
path, edit_dis = edit_distance(x,y,delta1)
print(f"edit distance: {edit_dis}")
visualise_edit(x,y,path)
# Out:
# los ---> kloc
# edit distance: 2
#  + k + los
# k : (l -> l) : os
# kl : (o -> o) : s
# klo : (s -> c) :
# kloc

# %%
for x,y in data:
    print(f"{x} ---> {y}")
    path, edit_dis = edit_distance(x,y,delta1)
    print(f"edit distance: {edit_dis}")
    visualise_edit(x,y,path)
    print()
# Out:
# los ---> kloc
# edit distance: 2
#  + k + los
# k : (l -> l) : os
# kl : (o -> o) : s
# klo : (s -> c) :
# kloc
#
# Łódź ---> Lodz
# edit distance: 3
#  : (Ł -> L) : ódź
# L : (ó -> o) : dź
# Lod : (ź -> z) :
# Lodz
#
# kwintesencja ---> quintessence
# edit distance: 5
#  : (k -> q) : wintesencja
# q : (w -> u) : intesencja
# quinte + s + sencja
# quintess : (e -> e) : ncja
# quintesse : (n -> n) : cja
# quintessen : (c -> c) : ja
# quintessenc * a
# quintessenc : (a -> e) :
# quintessence
#
# ATGAATCTTACCGCCTCG ---> ATGAGGCTCTGGCCCCTG
# edit distance: 7
# ATGA : (A -> G) : TCTTACCGCCTCG
# ATGAG : (T -> G) : CTTACCGCCTCG
# ATGAGGCT + C + TACCGCCTCG
# ATGAGGCTC : (T -> T) : ACCGCCTCG
# ATGAGGCTCT : (A -> G) : CCGCCTCG
# ATGAGGCTCTG : (C -> G) : CGCCTCG
# ATGAGGCTCTGG : (C -> C) : GCCTCG
# ATGAGGCTCTGGC : (G -> C) : CCTCG
# ATGAGGCTCTGGCCCC : (T -> T) : CG
# ATGAGGCTCTGGCCCCT * G
# ATGAGGCTCTGGCCCCTG

# %% [markdown]
# ### LCS

# %%
class Direction(Enum):
    NO_CHANGE = 0
    UP = 1
    LEFT = 2

# %%
def edit_distance_lcs(x, y):
    path = [[Direction.UP for _ in range(len(y) + 1)] for _ in range(len(x) + 1)]
    edit_table = [[0 for _ in range(len(y) + 1)] for _ in range(len(x) + 1)]
    for i in range(len(x) + 1):
        path[i][0] = Direction.UP
    for j in range(len(y) + 1):
        path[0][j] = Direction.LEFT

    for i in range(1, len(x) + 1):
        for j in range(1, len(y) + 1):
            if x[i - 1] != y[j - 1]:
                if edit_table[i - 1][j] > edit_table[i][j - 1]:
                    path[i][j] = Direction.UP
                    edit_table[i][j] = edit_table[i - 1][j]
                else:
                    path[i][j] = Direction.LEFT
                    edit_table[i][j] = edit_table[i][j - 1]
            else:
                edit_table[i][j] = edit_table[i - 1][j - 1] + 1
                path[i][j] = Direction.NO_CHANGE

    return path, edit_table[-1][-1]

# %%
def visualise_lcs(x, y, path):
    result = []
    i, j = len(x), len(y)
    while i != 0 or j != 0:
        step = path[i][j]
        if step == Direction.UP:
            i -= 1
        elif step == Direction.LEFT:
            j -= 1
        else:
            i -= 1
            j -= 1
            result.append(x[i])
    result.reverse()
    print("lcs: "+"".join(result))

# %%
x = "los"
y = "kloc"
print(f"{x} --- {y}")
path, edit_dis = edit_distance_lcs(x,y)
print(f"lcs length: {edit_dis}")
visualise_lcs(x,y,path)
print()
# Out:
# los --- kloc
# lcs length: 2
# lcs: lo

# %%
for x,y in data:
    print(f"{x} --- {y}")
    path, edit_dis = edit_distance_lcs(x,y)
    print(f"lcs length: {edit_dis}")
    visualise_lcs(x,y,path)
    print()
# Out:
# los --- kloc
# lcs length: 2
# lcs: lo
#
# Łódź --- Lodz
# lcs length: 1
# lcs: d
#
# kwintesencja --- quintessence
# lcs length: 8
# lcs: intesenc
#
# ATGAATCTTACCGCCTCG --- ATGAGGCTCTGGCCCCTG
# lcs length: 13
# lcs: ATGACTTCCCCTG

# %%
def lcs(x, y):
    ranges = [len(y)]
    y_letters = list(y)
    for char in x:
        positions = [j for j, l in enumerate(y_letters) if l == char]
        positions.reverse()
        for p in positions:
            k = bisect(ranges, p)
            if k == bisect(ranges, p - 1):
                if k < len(ranges) - 1:
                    ranges[k] = p
                else:
                    ranges[k:k] = [p]

    return len(ranges) - 1

# %%
def new_text(tokens):
    res = []
    for t in tokens:
        if random.random() >= 0.03:
            res.append(t)
    return res


def write_to_file(tokens, path):
    with open(path, 'w') as new_file:
        for token in tokens:
            new_file.write(token.text_with_ws)


def get_from_file(path):
    with codecs.open(path, 'r', 'utf-8') as new_file:
        return new_file.readlines()

# %%
def diff(x, y):
    edit_table = [[0 for _ in range(len(y) + 1)] for _ in range(len(x) + 1)]
    for i in range(len(x) + 1):
        for j in range(len(y) + 1):
            if i > 0 and j > 0:
                if x[i - 1] == y[j - 1]:
                    edit_table[i][j] = edit_table[i - 1][j - 1] + 1
                else:
                    edit_table[i][j] = max(edit_table[i - 1][j],
                                           edit_table[i][j - 1])
    res = []
    i = len(x) - 1
    j = len(y) - 1
    while i >= 0 and j >= 0:
        if x[i] == y[j]:
            i -= 1
            j -= 1
        elif edit_table[i][j - 1] >= edit_table[i - 1][j]:
            res.append(f"> ({j}) {y[j]}")
            j -= 1
        elif edit_table[i][j - 1] < edit_table[i - 1][j]:
            res.append(f"< ({i}) {x[i]}")
            i -= 1
    while i >= 0:
        res.append(f"< ({i}) {x[i]}")
        i -= 1

    while j >= 0:
        res.append(f"> ({j}) {y[j]}")
        j -= 1

    for line in reversed(res):
        print(line)

# %%
def test():
    tokenizer = Tokenizer(Polish().vocab)
    with open('assets/romeo-i-julia-700.txt', "r") as file:
        text = file.read()
        tokens = tokenizer(text)

        tokens1 = new_text(tokens)
        tokens2 = new_text(tokens)
        write_to_file(tokens1, 'assets/tokens1.txt')
        write_to_file(tokens2, 'assets/tokens2.txt')

        print(f"Length of token: {len(tokens)}")
        print(f"Length of first new token: {len(tokens1)}")
        print(f"Length of second new token: {len(tokens2)}")

        path, lcs1 = edit_distance_lcs(tokens1, tokens2)
        print(f"lcs1: {lcs1}")
        print(f"lcs2: {lcs(tokens1, tokens2)}")

        tokens1 = get_from_file('assets/tokens1.txt')
        tokens2 = get_from_file('assets/tokens2.txt')
        diff(tokens1, tokens2)

# %%
test()
# Out:
# Length of token: 2272
# Length of first new token: 2209
# Length of second new token: 2215
# lcs1: 2155
# lcs2: 2155
# < (2) Romeo Julia
#
# > (2) Romeo i Julia
#
# < (21)  * SAMSON, GRZEGORZ — Kapuleta
#
# > (21)  * SAMSON, GRZEGORZ — słudzy Kapuleta
#
# < (29)  * PANI KAPULET — małżonka
#
# > (29)  * PANI KAPULET — małżonka Kapuleta
#
# < (37) Rzecz odbywa się przez większą część sztuki w Weronie, przez część piątego aktu w Mantui.
#
# > (37) odbywa się przez większą część sztuki w Weronie, przez część piątego aktu w Mantui.
#
# < (45) Dwa rody, zacne jednako i sławne —Tam, gdzie się rzecz ta rozgrywa, w Weronie,
#
# > (45) Dwa rody, zacne jednako i sławne —
#
# > (46) Tam, gdzie się rzecz ta rozgrywa, w Weronie,
#
# < (49) Z łon tych dwu wrogów wzięło bowiem
#
# > (50) Z łon tych dwu wrogów wzięło bowiem życie,
#
# < (50) Pod z gwiazd, kochanków dwoje;
#
# > (51) Pod najstraszliwszą z gwiazd, kochanków dwoje;
#
# < (59) Które otoczcie cierpliwymi względy,
#
# > (60) Które otoczcie względy,
#
# < (69) SCENA PIERWSZA
#
# > (70) SCENA
#
# < (70)
#
# < (71) / Plac publiczny. Wchodzą Samson i Grzegorz w tarcze i miecze. /
#
# > (71)
#
# > (72) / Plac publiczny. Wchodzą Samson i Grzegorz uzbrojeni w tarcze i miecze. /
#
# < (72)
#
# < (73)
#
# < (74) SAMSON
#
# > (73)
#
# < (76) Dalipan, Grzegorzu, nie będziem darli pierza.
#
# > (77) Dalipan, Grzegorzu, nie będziem darli
#
# < (79) GRZEGORZ
#
# > (78)
#
# < (81) Ma się bobyśmy byli zdziercami.
#
# > (80) GRZEGORZ
#
# > (81)
#
# > (82) Ma się rozumieć, bobyśmy byli zdziercami.
#
# < (84) SAMSON
#
# > (85) SAMSONAle będziemy koty, jak z nami zadrą.
#
# < (85)
#
# < (86) Ale będziemy darli jak z nami zadrą.
#
# < (106) Te psy z domu Montekich mię mogą bardzo łatwo.GRZEGORZRozruchać się tyle znaczy co ruszyć się z miejsca; być walecznym jest to stać nieporuszenie: pojmuję więc, że skutkiem rozruchania się twego będzie - drapnięcie.
#
# > (105) Te psy z domu Montekich rozruchać mię mogą bardzo łatwo.
#
# < (109) SAMSON
#
# < (111) Te psy z domu Montekich rozruchać mię mogą tylko do stania na miejscu. Będę jak mur dla każdego mężczyzny i każdej z tego domu.
#
# > (109)
#
# > (110) Rozruchać się tyle znaczy co ruszyć się z miejsca; być walecznym jest to stać nieporuszenie: pojmuję więc, że skutkiem rozruchania się twego będzie - drapnięcie.
#
# > (111)
#
# > (112)
#
# > (113) SAMSON
#
# > (114)
#
# > (115) Te psy z domu Montekich rozruchać mię mogą tylko do stania na miejscu. Będę jak mur dla każdego mężczyzny i każdej kobiety z tego domu.
#
# < (116) To właśnie pokazuje twoją słabą stronę; dla nikogo niestraszny i tylko słabi go się trzymają.
#
# > (120) To właśnie pokazuje słabą stronę; dla nikogo niestraszny i tylko słabi go się trzymają.
#
# < (121) Prawda, dlatego to kobiety, jako najsłabsze, tulą się zawsze do muru. Ja też odtrącę od muru ludzi Montekich, a kobiety Montekich przyprę do muru.GRZEGORZ
#
# > (125) Prawda, dlatego to kobiety, jako najsłabsze, tulą się zawsze do muru. Ja też odtrącę od muru ludzi Montekich, a kobiety Montekich przyprę do muru.
#
# > (126)
#
# > (127)
#
# > (128) GRZEGORZ
#
# < (128) Mniejsza mi o to, będę nieubłagany. Pobiwszy ludzi, wywrę wściekłość na kobietach: rzeź między nimi sprawię.
#
# > (135) Mniejsza mi o to, będę nieubłagany. Pobiwszy ludzi, wywrę na kobietach: rzeź między nimi sprawię.
#
# < (133) Rzeź kobiet przedsiębrać?
#
# > (140) Rzeź kobiet chcesz przedsiębrać?
#
# < (143) Tym lepiej, że się do bo gdybyś się liczył do ryb, to byłbyś pewnie sztokfiszem. Weź no się za instrument, bo oto nadchodzi dwóch domowników Montekiego.
#
# > (150) Tym lepiej, że się liczysz do zwierząt; bo gdybyś się liczył do ryb, to byłbyś pewnie sztokfiszem. Weź no się za instrument, bo oto nadchodzi dwóch domowników Montekiego.
#
# < (150) Mój giwer już dobyty: zaczep ich, ja stanę z
#
# > (157) Mój giwer już dobyty: zaczep ich, ja stanę z tyłu.
#
# < (155) Gwoli drapania?
#
# > (162) Gwoli
#
# < (170) Miejmy prawo za sobą, niech oni zaczną.
#
# > (177) Miejmy za sobą, niech oni zaczną.
#
# < (178) SAMSONNie jak chcą, ale jak śmią. Ja im gębę wykrzywię; hańba im, jeśli to ścierpią.
#
# > (185) SAMSON
#
# < (179)
#
# > (187) Nie jak ale jak śmią. Ja im gębę wykrzywię; hańba im, jeśli to ścierpią.
#
# < (181) ABRAHAM
#
# > (188)
#
# < (183) Skrzywiłeś się na mości panie?
#
# > (190) ABRAHAM
#
# > (191)
#
# > (192) Skrzywiłeś się na nas, mości panie?
#
# < (188) Nie inaczej, skrzywiłem się.
#
# > (197) Nie inaczej, skrzywiłem
#
# < (198) do Grzegorza /
#
# > (207) / do Grzegorza /
#
# < (199)
#
# < (200) Będziemy–ż mieli prawo za sobą, jak powiem: tak
#
# > (208)
#
# > (209) Będziemy–ż mieli prawo za sobą, jak powiem: tak jest?
#
# < (215) / do Abrahama /
#
# > (224) / do /
#
# < (237) Niech i będzie.
#
# > (246) Niech i tak będzie.
#
# < (244) / na stronie do Samsona /
#
# > (253) na stronie do Samsona /
#
# < (245)
#
# < (246) Powiedz: lepszy. Oto nadchodzi jeden z krewnych mego pana.
#
# > (254)
#
# > (255) Powiedz: lepszy. Oto nadchodzi jeden z krewnych mego pana.SAMSON
#
# < (247)
#
# < (248)
#
# < (249) SAMSON
#
# < (254) ABRAHAMKłamiesz.
#
# > (260) ABRAHAM
#
# > (261)
#
# > (262) Kłamiesz.
#
# < (268) / Tybalt. /
#
# > (276) / Wchodzi Tybalt. /
#
# < (277) BENWOLIO
#
# < (279) Przywracam tylko pokój. Włóż miecz
#
# > (286)
#
# > (287) Przywracam tylko pokój. Włóż miecz nazad
#
# < (285) Z gołym orężem pokój? Nienawidzę
#
# > (293) gołym orężem pokój? Nienawidzę
#
# < (286) wyrazu, jak nienawidzę
#
# < (287) wszystkich Montekich i ciebie.
#
# > (294) Tego wyrazu, tak jak nienawidzę
#
# > (295) Szatana, wszystkich Montekich i ciebie.
#
# < (290) / Walczą. Nadchodzi kilku przyjaciół partii i mieszają się do zwady; wkrótce potem wchodzą mieszczanie z pałkami. /
#
# > (298) / Walczą. Nadchodzi kilku przyjaciół obu partii i mieszają się do zwady; wkrótce potem wchodzą mieszczanie z pałkami. /
#
# < (298) / Wchodzą Kapulet i Pani Kapulet /
#
# > (306) / Wchodzą Kapulet i Pani Kapulet
#
# < (303) Co za hałas? Podajcie mi
#
# > (311) Co za hałas? Podajcie mi długi
#
# < (310)
#
# > (320) KAPULET
#
# > (322) Miecz, mówię! Stary nadchodzi.
#
# < (314) Miecz, mówię! Stary Monteki nadchodzi.
#
# < (322) Ha! nędzny Kapulecie!
#
# > (330) nędzny Kapulecie!
#
# < (343) Pod karą tortur wypuśćcie natychmiast
#
# > (351) Pod karą tortur wypuśćcie
#
# < (344) Z dłoni skrwawionych tę broń buntowniczą
#
# < (345) I posłuchajcie tego, co niniejszym
#
# > (352) Z dłoni skrwawionych tę broń buntowniczą
#
# > (353) posłuchajcie tego, co
#
# < (346) Wasz rozjątrzony książę postanawia.
#
# < (347) Domowe starcia, z marnych słów zrodzone
#
# < (348) Przez was, Monteki Kapulecie,
#
# > (354) Wasz książę postanawia.
#
# > (355) Domowe starcia, z marnych słów zrodzone
#
# > (356) Przez was, Monteki oraz Kapulecie,
#
# < (353) I w stare dłonie stare ująć miecze,
#
# > (361) I stare dłonie stare ująć miecze,
#
# < (361) Na ratusz, gdzie ci dokładnie w tym względzie
#
# > (369) Na ratusz, ci dokładnie w tym względzie
#
# < (366) / Książę z orszakiem wychodzi. Podobnież Kapulet, Pani Kapulet, Tybalt, i słudzy. /
#
# > (374) / Książę z orszakiem wychodzi. Kapulet, Pani Kapulet, Tybalt, obywatele i słudzy. /
#
# < (377) Nieprzyjaciela naszego pachołcy
#
# > (385) naszego pachołcy
#
# < (378) I wasi już się bili, kiedym nadszedł;
#
# < (379) Dobyłem broni, aby ich
#
# > (386) I wasi już się bili, kiedym nadszedł;
#
# > (387) Dobyłem broni, aby ich rozdzielić:
#
# < (380) Wtem wpadł szalony Tybalt z gołym
#
# > (388) Wtem wpadł szalony Tybalt z gołym mieczem,
#
# < (384) Jego zamachów. Gdyśmy tak ze sobą
#
# > (392) Jego zamachów. Gdyśmy tak ze
#
# < (385) Cięcia i pchnięcia zbiegł się
#
# < (386) Większy tłum ludzi; z obu stron walczono,
#
# > (393) i pchnięcia zamieniali, zbiegł się
#
# > (394) Większy tłum ludzi; z obu
#
# < (392) Lecz Romeo? Widział żeś go dzisiaj?
#
# > (400) Lecz gdzież Romeo? Widział żeś go dzisiaj?Jakże się cieszę, że nie był w tym starciu.
#
# < (393) Jakże się cieszę, że nie był w tym starciu.
#
# < (402) południowi od naszego miasta.
#
# > (409) Ku południowi od naszego miasta.
#
# < (403) Tam, już tak rano, syn wasz się przechadzał.
#
# > (410) Tam, już tak rano, syn wasz przechadzał.
#
# < (406) w najciemniejszej ukrył się gęstwinie.
#
# > (413) I w najciemniejszej ukrył się gęstwinie.
#
# < (407) Pociąg ten jego do odosobnienia
#
# < (408) Mierząc mym własnym (serce nasze bowiem
#
# > (414) Pociąg ten jego do odosobnienia
#
# > (415) mym własnym (serce nasze bowiem
#
# < (409) Jest najczynniejsze, kiedyśmy samotni),
#
# < (410) Nie przeszkadzałem mu w jego
#
# > (416) Jest najczynniejsze, kiedyśmy samotni),
#
# > (417) Nie przeszkadzałem mu w jego dumaniach
#
# < (411) I w inną stronę się udałem, chętnieStroniąc od tego, co rad mnie unikał.
#
# > (418) I w inną stronę się udałem, chętnie
#
# > (419) Stroniąc od tego, co rad mnie unikał.
#
# < (416) Nieraz o świcie już go tam widziano
#
# > (424) o świcie już go tam widzianoLzami poranną mnożącego rosę,
#
# < (417) Lzami poranną mnożącego rosę,
#
# < (422) On, uciekając od widoku światła,
#
# > (429) On, uciekając od światła,
#
# < (423) Co tchu zamykał się w swoim pokoju;
#
# < (424) Zasłaniał okna przed jasnym dnia blaskiem
#
# > (430) Co tchu zamykał się w swoim pokoju;
#
# > (431) Zasłaniał okna przed jasnym blaskiem
#
# < (425) I sztuczną sobie ciemnicę utwarzał.
#
# < (426) czarne bezdroża dusza jego zajdzie,
#
# > (432) I sztuczną sobie ciemnicę utwarzał.
#
# > (433) W czarne bezdroża dusza jego zajdzie,
#
# < (427) Jeśli się na to lekarstwo nie znajdzie.BENWOLIO
#
# > (434) Jeśli się na to lekarstwo nie znajdzie.
#
# > (435)
#
# > (436)
#
# > (437) BENWOLIO
#
# < (434) Nie i z niego wydobyć nie mogę.
#
# > (444) Nie znam i z niego wydobyć nie mogę.
#
# < (445) Lecz on jedyny powiernik swych
#
# > (455) Lecz on jedyny powiernik swych smutków.
#
# < (451) Gdybyśmy mogli tych trosk zarodka,
#
# > (461) Gdybyśmy mogli dojść tych trosk zarodka,
#
# < (515)                         Jak to? brak miłości?
#
# > (525)                         to? brak miłości?
#
# < (518) ROMEOBrak jej tam, skąd bym pragnął wzajemności.
#
# > (528) ROMEO
#
# > (529)
#
# > (530) Brak jej tam, skąd bym wzajemności.
#
# < (524) Miłość jest w gruncie tak srogą tyranką?ROMEO
#
# > (536) Miłość jest w gruncie tak srogą
#
# < (525)
#
# < (526) Niestety! Czemuż, z zasłoną na skroni,
#
# > (537)
#
# > (538)
#
# < (527) Miłość na oślep zawsze cel swój goni!
#
# > (539) ROMEO
#
# > (540)
#
# > (541) Niestety! Czemuż, z zasłoną skroni,
#
# > (542) na oślep zawsze cel swój goni!
#
# < (530) W grze tu nienawiść wielka, lecz i miłość.O! wy sprzeczności niepojęte dziwa!
#
# > (545) W grze tu nienawiść wielka, lecz i miłość.
#
# > (546) O! wy sprzeczności niepojęte dziwa!
#
# < (566) To dym, co z parą się unosi;
#
# > (582) To dym, co z parą westchnień się unosi;
#
# < (573) / chce odejść /
#
# > (589) / odejść /
#
# < (585) To nie Romeo, co rozmawia z tobą.
#
# > (601) To nie Romeo, rozmawia z tobą.
#
# < (609) Pisać testament: będzie–ż to wezwanieDobre dla tego, kto jest w tak złym stanie?
#
# > (625) Pisać testament: będzie–ż to wezwanie
#
# > (626) Dobre dla tego, kto jest w tak stanie?
#
# < (625) BENWOLIOW piękny cel trafić najłatwiej.
#
# > (642) BENWOLIO
#
# < (626)
#
# > (644)                         W piękny cel trafić najłatwiej.
#
# < (628) ROMEO
#
# > (645)
#
# < (630) A właśnieś chybił. Niczym tu
#
# > (647) ROMEO
#
# > (648)
#
# > (649) A właśnieś chybił. Niczym tu kołczany
#
# < (631) Kupida; ona ma naturę Diany;
#
# > (650) Kupida; ona ma
#
# < (634) Szydzi z nawału zaklęć
#
# > (653) Szydzi z nawału zaklęć oblężniczych;
#
# < (638) Że kiedy umrze, do grobu z nią zstąpi
#
# > (657) Że kiedy umrze, do grobu z nią
#
# < (644) Wiecznie–ż chce sama zostać swym bogactwem?
#
# > (663) Wiecznie–ż chce sama zostać z swym bogactwem?
#
# < (650) piękność, którą własna srogość strawia,
#
# > (669) Bo piękność, którą własna srogość strawia,
#
# < (651) Całą potomność piękności pozbawia.
#
# < (652) Zbyt piękna, zbyt mądra zarazem;
#
# > (670) Całą potomność piękności pozbawia.
#
# > (671) Zbyt ona piękna, zbyt mądra zarazem;
#
# < (653) Zbyt mądrze piękna: stąd istnym jest głazem.
#
# < (654) Przysięgła nigdy nie kochać i dzięki
#
# < (655) Temu skazanym - wieczne cierpieć
#
# > (672) Zbyt mądrze piękna: stąd jest głazem.
#
# > (673) Przysięgła nigdy nie kochać i dzięki
#
# > (674) Temu skazanym - wieczne cierpieć męki.
#
# < (665) Doradź–że także, jakim bym sposobemMógł przestać myśleć.
#
# > (684) Doradź–że także, jakim bym sposobem
#
# > (685) Mógł przestać
